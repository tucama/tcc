# %%
import pandas as pd
import numpy as np
import os
import re

# %%
regex_pattern="[1-9a-z]{4}_"
files = os.listdir(".")

files_per_pdb = {}

for file in files:
        # Get the first `prefix_length` characters of the file name
        prefix = file[:4]
        files_per_pdb[prefix].appendfile
        
#matching_files = [file for file in files if re.match(file)]
files_per_pdb
# Out:
# dict_items([('1a4y', ['1a4y_B_R31_A_B.lrd', '1a4y_A_K320_A_B.lrd', '1a4y_A_W261.lrd', '1a4y_B_H114_A_B.lrd', '1a4y_B_R5_A_B.lrd', '1a4y_A_W263_A_B.lrd', '1a4y_B_H84.lrd', '1a4y_B_H84_A_B.lrd', '1a4y_A_Y434_A_B.lrd', '1a4y_A_Y437_A_B.lrd', '1a4y_A_E344_A_B.lrd', '1a4y_A_Y437.lrd', '1a4y_B_E108_A_B.lrd', '1a4y_A_D435_A_B.lrd', '1a4y_A_E401_A_B.lrd', '1a4y_A_K320.lrd', '1a4y_A_I459_A_B.lrd', '1a4y_B_E108.lrd', '1a4y_A_W263.lrd', '1a4y_A_E401.lrd', '1a4y_A_Y434.lrd', '1a4y_B_R31.lrd', '1a4y_B.lrd', '1a4y_A_D435.lrd', '1a4y_B_H114.lrd', '1a4y_B_R5.lrd', '1a4y_A_E344.lrd', '1a4y_A.lrd', '1a4y_A_W261_A_B.lrd', '1a4y_wt_A_B.lrd', '1a4y_A_I459.lrd']), ('1dqj', ['1dqj_C_K97_AB_C.lrd', '1dqj_A_Y50.lrd', '1dqj_C_D101.lrd', '1dqj_C_S100_AB_C.lrd', '1dqj_B_D32.lrd', '1dqj_wt_AB_C.lrd', '1dqj_B_W98_AB_C.lrd', '1dqj_C_K97.lrd', '1dqj_C.lrd', '1dqj_C_T89_AB_C.lrd', '1dqj_A_Y50_AB_C.lrd', '1dqj_C_R21_AB_C.lrd', '1dqj_C_Y20_AB_C.lrd', '1dqj_C_L75_AB_C.lrd', '1dqj_C_S100.lrd', '1dqj_C_Y20.lrd', '1dqj_B_
# ...

# %%
lrd_entries = {}
for file in files:
        entry = str(file).rsplit('.', 1)[0]
        print(entry)
        print(file)
        #pd.read_table(f"./{i}", sep=r'\s+', skiprows=1, index_col=0)
# Out:
# 1a4y_B_R31_A_B
# 1a4y_B_R31_A_B.lrd
# 1dqj_C_K97_AB_C
# 1dqj_C_K97_AB_C.lrd
# 1ktz_B_I29
# 1ktz_B_I29.lrd
# 1jtg_A_E79_A_B
# 1jtg_A_E79_A_B.lrd
# 1jtg_B_Y51
# 1jtg_B_Y51.lrd
# 1vfb_C_D18
# 1vfb_C_D18.lrd
# 1emv_A_S46
# 1emv_A_S46.lrd
# 1dqj_A_Y50
# 1dqj_A_Y50.lrd
# 1jtg_B_Y143
# 1jtg_B_Y143.lrd
# 1jtg_B_W162
# 1jtg_B_W162.lrd
# 1emv_A_E39_A_B
# 1emv_A_E39_A_B.lrd
# 1dqj_C_D101
# 1dqj_C_D101.lrd
# 1dqj_C_S100_AB_C
# 1dqj_C_S100_AB_C.lrd
# 1jtg_B_W112_A_B
# 1jtg_B_W112_A_B.lrd
# 1dqj_B_D32
# 1dqj_B_D32.lrd
# 1jtg_A_Q74
# 1jtg_A_Q74.lrd
# 1a4y_A_K320_A_B
# 1a4y_A_K320_A_B.lrd
# 1a4y_A_W261
# 1a4y_A_W261.lrd
# 1dvf_A_S93_AB_CD
# 1dvf_A_S93_AB_CD.lrd
# 1a4y_B_H114_A_B
# 1a4y_B_H114_A_B.lrd
# 1emv_A_T25_A_B
# 1emv_A_T25_A_B.lrd
# 1dqj_wt_AB_C
# 1dqj_wt_AB_C.lrd
# 1jtg_A_M104
# 1jtg_A_M104.lrd
# 1emv_A_T25
# 1emv_A_T25.lrd
# 1jtg_B_Y51_A_B
# 1jtg_B_Y51_A_B.lrd
# 1jtg_B_G48
# 1jtg_B_G48.lrd
# 1dqj_B_W98_AB_C
# 1dqj_B_W98_AB_C.lrd
# 1jtg_A_Q74_A_B
# 1jtg_A_Q74_A_B.lrd
# 1jtg_A_Y80_A_B
# ...

# %%
print([for file in pdb for pdb in files_per_pdb])
data_frames = [pd.read_csv(file) for file in file_names]
# Out:
#   File "/tmp/ipykernel_211223/4270766648.py", line 1
#     print([for file in pdb for pdb in files_per_pdb])
#            ^
# SyntaxError: invalid syntax

# %%
test = pd.read_table("./1a4y_A.lrd", sep=r'\s+', skiprows=1, index_col=0)
test
# Out:
#      atom  nucleophilicity  electrophilicity  radicality  netphilicity  \
# n
# 1       N         0.000007          0.001342    0.000674      0.001335
# 2       H         0.000000          0.000298    0.000149      0.000298
# 3       H         0.000000          0.000279    0.000140      0.000279
# 4       H         0.000000          0.000310    0.000155      0.000309
# 5       C         0.000021          0.002293    0.001157      0.002272
# ...   ...              ...               ...         ...           ...
# 6995   Na         0.000000          0.014614    0.007307      0.014614
# 6996   Na         0.000000          0.014614    0.007307      0.014614
# 6997   Na         0.000000          0.014614    0.007307      0.014614
# 6998   Na         0.000000          0.014614    0.007307      0.014614
# 6999   Na         0.000000          0.014614    0.007307      0.014614
#
#       hardness_Vee  hardness_lcp  Fukui_pot_left  Fukui_pot_right  \
# n
# ...
